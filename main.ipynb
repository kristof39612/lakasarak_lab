# %%
dataset_train = "dataset\\ingatlan.com_training_final.csv"
dataset_val = "dataset\\ingatlan.com_testing_final.csv"
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
df = pd.read_csv(dataset_train, delimiter='|')
df
# Out:
#           county           city  postcode property_type  \
# 0       Budapest   Budapest IV.       NaN          flat
# 1       Budapest  Budapest XIV.    1147.0          flat
# 2       Budapest  Budapest XIV.       NaN          flat
# 3       Budapest   Budapest II.    1024.0          flat
# 4       Budapest  Budapest XII.    1126.0          flat
# ...          ...            ...       ...           ...
# 183560  Budapest  Budapest VII.    1076.0          flat
# 183561  Budapest  Budapest VII.       NaN          flat
# 183562  Budapest   Budapest IV.       NaN          flat
# 183563  Budapest   Budapest IV.       NaN          flat
# 183564  Budapest    Budapest V.    1052.0          flat
#
#                            property_subtype property_condition_type  \
# 0       prefabricated panel flat (for sale)                    good
# 1                     brick flat (for sale)                   novel
# 2                     brick flat (for sale)                  medium
# 3                     brick flat (for sale)                   novel
# 4                     brick flat (for sale)                    good
# ...                                     ...                     ...
# 183560                brick flat (for sale)                  medium
# 183561                brick flat (for sale)         to_be_renovated
# 183562                brick flat (for sale)                 renewed
# 183563  prefabricated panel flat (for sale)                 renewed
# 183564                brick flat (for sale)                   novel
#
#        property_floor building_floor_count    view_type orientation  ...  \
# 0                   3                   10  garden view        east  ...
# 1        ground floor                  NaN          NaN         NaN  ...
# 2                   4                  NaN          NaN         NaN  ...
# 3            basement                  NaN  street view         NaN  ...
# 4        ground floor                  NaN  garden view         NaN  ...
# ...               ...                  ...          ...         ...  ...
# 183560   ground floor                  NaN          NaN  south-west  ...
# 183561              2                  NaN          NaN         NaN  ...
# 183562   ground floor                    1  street view       south  ...
# 183563              1                    4          NaN       south  ...
# 183564              1                  NaN          NaN        west  ...
#
#        room_cnt small_room_cnt  created_at  property_area  balcony_area  \
# 0           1.0            1.0  2015-02-09           35.0           0.0
# 1           1.0            0.0  2015-02-09           35.0           0.0
# 2           2.0            0.0  2015-02-09           50.0           0.0
# 3           1.0            1.0  2015-02-09           50.0           0.0
# 4           1.0            2.0  2015-02-09           50.0           0.0
# ...         ...            ...         ...            ...           ...
# 183560      1.0            0.0  2016-08-29           30.0           0.0
# 183561      2.0            0.0  2016-08-29           45.0           0.0
# 183562      1.0            0.0  2016-08-29           40.0           0.0
# 183563      2.0            1.0  2016-08-29           65.0           4.0
# 183564      2.0            0.0  2016-08-29           40.0           0.0
#
#        price_created_at  ad_view_cnt  active_days  label      nr
# 0                   9.5        702.0         23.0      0       7
# 1                  11.2         42.0          6.0      0       8
# 2                  14.5        504.0         96.0      1       9
# 3                  15.3         39.0          1.0      0      11
# 4                  17.9        114.0         27.0      1      13
# ...                 ...          ...          ...    ...     ...
# 183560             11.0         40.0          1.0      0  394166
# 183561             20.5         10.0          1.0      0  394167
# 183562              8.5        339.0          1.0      0  394171
# 183563             18.9         79.0          1.0      0  394173
# 183564             42.0         22.0          1.0      0  394178
#
# [183565 rows x 23 columns]
